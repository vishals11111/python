# %% [markdown]
# **Functions**
# - reuse of code
#
# - imagine you want to calculate tax of all tax payers
#
# - suppose there are 100 tax payers are there
#
# - in order to calculate tax we required 500 lines
#
# - this is not the good code
#
# - because 5 lines we are repaeting for memebers
#
# - here functions will help us how to use only these 5 lines to all 100 tax payers
# -

# %%
#salary=eval(input('enter the salary'))

# %%
#syntax
#def <function name>():
    #st1
    #st2

# %%
a=10
b=20
add=a+b
print(add)
# Out:
# 30

# %%
def addition():
    a=10
    b=20
    add=a+b
    print(add)
    
addition()
# Out:
# 30

# %% [markdown]
# - first mistake you will forget the brackets while definr function
#
# - second mistake will be forget the colon
#
# - third will not give the indentation
#
# - forget the allignment'
#
# - variable name and function name must be different
#
# - while colling the function dont forgrt the colon
#
# - function is also call methods
#
# - whenever function is there brackets must be there
# -  define function eill not give the errors will disply after calling the function
# -

# %% [markdown]
# **functions without argumnets**
# - when we define function we will privide brackets
# - inside these brackets we can provide value
# - this value call arguments & parameter
# - if we dont provide arguments this is call function wothout parameter

# %%
def addition():
    a=10
    b=20
    add=a+b
    print(add)
    
addition
# Out:
# <function __main__.addition()>

# %%
def add1():
    n1=30
    n2=8866
    add=n1111+n2
    print(add)
add1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4     add=n1111+n2
#       5     print(add)
# ----> 6 add1()
#
# Cell In[6], line 4, in add1()
#       2 n1=30
#       3 n2=8866
# ----> 4 add=n1111+n2
#       5 print(add)
#
# NameError: name 'n1111' is not defined

# %%
#create function 
def average():
    no1=eval(input("enter the value"))
    no2=eval(input("enter the value"))
    no3=eval(input("enter the value"))
    avg=round((no1+no2+no3)/3,2)
    print(avg)
average()

# %%
def bill_t():
    
    bill=eval(input("eneytr the bill amount"))
    tip=eval(input("enter the tip per"))
    tip_bill=tip*bill/100
    totalb=bill+tip_bill

    print(totalb)
bill_t()

# %%
def area1():
    import math
    pi=math.pi
    r=eval(input("please provide the radious"))
    area_of_c=round(pi*r*r,2)
    print(area_of_c)
area1()

# %%
def tri():
    
    breadt=eval(input("enter the value breadth"))
    height=eval(input("enter the value height"))
    areat=round(0.5*breadt*height,2)
    print(areat)
tri()

# %%
def evenodd():
    a1=eval(input('enter the no'))
    if a1%2==0:
        print(f"this is even no {a2}")
    else:
        print(f"thid is odd no{a1}")
evenodd()

# %%
#find out positive negative
def pos():
    a2=eval(input("enter the value"))
    if a2>0:
        print("this is positive")
    elif a2==0:
        print("this is zero")
    else: 
        print("this is negative:")
pos()
# Out:
# enter the value 6
# this is positive

# %%
#find out gretesr

# %% [markdown]
# **function with arguments* *
# -how many variable are there in given function
#   - input variables: user will provide
#   - suppose n1 and n2 are the input variables
#   - output variables: we are creating the output variables

# %%
def add2(n1,n2):
    ADD=n1+n2
    print(ADD)
add2(23,32)

# %%
def average(mun1,mun2):
    print(mun1)
    print(mun2)
    mun3=eval(input("enter the value for mun3"))
    av=round((mun1+mun2+mun3)/3,)
    print(av)
average(10,20)

# %%
def average(mun1):
    print(mun1)
    
    #mun3=eval(input("enter the value for mun3"))
    av=round((mun1)/1,)
    print(av)
average(eval(input("enter the value")))

# %%
import random
def average(mun1):
    print(mun1)
    
    #mun3=eval(input("enter the value for mun3"))
    av=round((mun1)/1,)
    print(av)
average(random.randint(1,20))

# %% [markdown]
# - hard code
#
# - eval(input)
#
# - random.randint()

# %%
average(10)
average(eval(input("entr")))
average(random.randint(1,2))

# %%
def bill(amount,tip_rate):
    tip_amount=(tip_rate*amount)/100
    total=tip_amount+amount
    print(total)
bill(1000,10)

# %%
def bill(amount,tip_rate):
    tip_amount=(tip_rate*amount)/100
    total=tip_amount+amount
    print(total)
bill(eval(input("emter ")),eval(input("enter"))  )
# Out:
# emter  1000
# enter 10
# 1100.0

# %%
import random
def bill(amount,tip_rate):
    tip_amount=(tip_rate*amount)/100
    total=tip_amount+amount
    print(total)
bill(random.randint(100,1000) ,eval(input("enter the tiprate")) )
# Out:
# enter the tiprate 10
# 159.5

# %% [markdown]
# **default argument**
# -

# %%
def billing(bill,tip_rate=20):
    print("the bill is",bill)
    print("the tip rate is",tip_rate)
    tip_amount=(tip_rate*bill)/100
    total=tip_amount+bill
    print(total)
billing(1000)
# Out:
# the bill is 1000
# the tip rate is 20
# 1200.0

# %% [markdown]
# **case2**
# - all default character must be assign after non default aegument
# -

# %% [markdown]
# **case 3**
# - default value can be override

# %%
def billing(bill=2000,tip_rate=20):
    bill=5000
    print("the bill is",bill)
    print("the tip rate is",tip_rate)
    tip_amount=(tip_rate*bill)/100
    total=tip_amount+bill
    print(total)
billing(1000,40)
# Out:
# the bill is 5000
# the tip rate is 40
# 7000.0

# %% [markdown]
# **global and local variable**
# - local variable means which is define inside the function and accsible only in the block
# - global variable is accessible anywhere in program file

# %%
def average():
    n1=eval(input("enter"))
    n2=eval(input("enter"))
    n3=eval(input("enter"))
    avg=(n2+n3+n1)/3
    print(avg)
average()
# Out:
# enter 33
# enter 34
# enter 34
# 33.666666666666664

# %%
def average(n1,n2,n3):
    avg=(n2+n3+n1)/3
    print(avg)
average(12,12,12)
# Out:
# 12.0

# %%
def average(n1,n2,n3=33):
    print(n3)
    avg=round((n2+n3+n1)/3,4)
    print(avg)
average(12,12)
# Out:
# 33
# 19.0

# %%
def add():
    print(a+b)
add()
a=20
b=10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 def add():
#       2     print(a+b)
# ----> 3 add()
#       4 a=20
#       5 b=10
#
# Cell In[1], line 2, in add()
#       1 def add():
# ----> 2     print(a+b)
#
# NameError: name 'a' is not defined

# %%
def add():
    print(a+b)
    a=20
    b=10
add()
# Out:
# 30

# %% [markdown]
# ** use the local varible outside the function block **
# - we need to use global keyword for use local variable in the out side of function
# - we can aslo use return keyword for use local varible as global

# %%
def add11():
    
    a1=20
    b1=10
    return(a1+b1)
a=add11()   
a
# Out:
# 30

# %%
a
# Out:
# 20

# %%
def add11():
    
    a=20
    b=10
    print(a,b)
    return(b,a)
a,b=add11()   
print(a, b)
add11()
# Out:
# 20 10
# 10 20
# 20 10
# (10, 20)

# %%
def add11():
    
    a=20
    b=10
    add=a+b
    return(add,a,b)
val=add11()   
val
# Out:
# (30, 20, 10)

# %% [markdown]
# **function in function**

# %%
def greet1():
    print("===calling function===")
    print("good morning")
def greet2():
    print("===calling function===")
    print("good night")
greet1()
greet2()
# Out:
# ===calling function===
# good morning
# ===calling function===
# good night

# %%
def greet1():
    print("===calling function greet1===")
    greet2()
    print("good morning")
def greet2():
    print("===calling function greet2===")
    print("good night")
greet1()
# Out:
# ===calling function greet1===
# ===calling function greet2===
# good night
# good morning

# %%
def greet1():
    print("===calling function greet1===")
    
    print("good morning")
def greet2():
    print("===calling function greet2===")
    greet1()
    print("good night")
greet2()
# Out:
# ===calling function greet2===
# ===calling function greet1===
# good morning
# good night

# %%
def greet1():
    print("===calling function greet1===")
    
    print("good morning")
    greet1()
greet1()
# Out:
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ===calling function greet1===
# good morning
# ...

# %%
def add():
    print(a+b)
def sub():
    print(a-b)
def math_operation():
    add()
    sub()
math_operation()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       6     add()
#       7     sub()
# ----> 8 math_operation()
#
# Cell In[16], line 6, in math_operation()
#       5 def math_operation():
# ----> 6     add()
#       7     sub()
#
# Cell In[16], line 2, in add()
#       1 def add():
# ----> 2     print(a+b)
#
# NameError: name 'b' is not defined

# %%
a=11
b=22

def add():
    print(a+b)
def sub():
    print(a-b)
def math_operation():
    add()
    sub()
math_operation()
# Out:
# 33
# -11

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def math_operation():
    add(99,100)
    sub(100,99)
math_operation()
# Out:
# 199
# 1

# %%
#calculator program

def add11(a,b):
    print(a+b)
def sub11(a,b):
    print(a-b)
def mul11(a,b):
    print(a*b)
def div11(a,b):
    print(a/b)

def mathop(a,b):
    op=eval(input("enter the opreration 1 to 4 for add,sub,mul,div accordingly"))
    if op==1:
        add11(a,b)
    elif op==2:
        sub11(a,b)
    elif op==3:
        mul11(a,b)
    elif op==4:
        div11(a,b)
    else:
        print("invalid")
mathop(a,b)
# Out:
# enter the opreration 1 to 4 for add,sub,mul,div accordingly 5
# invalid
